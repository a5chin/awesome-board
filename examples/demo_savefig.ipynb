# %%
from board import Board

# %%
board = Board("logs")
board.savefig(output_dir="outputs", extension="png")
# Out:
# [2022-04-06 02:41:11] :board.board: [INFO] train/loss saved.
# [2022-04-06 02:41:11] :board.board: [INFO] train/accuracy saved.
# [2022-04-06 02:41:11] :board.board: [INFO] train/lr saved.
